# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
corona_df=pd.read_csv(r"E:\New folder\COVID19_line_list_data.csv")
corona_df.head(2)
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
#
#                                               source  \
# 0               Shenzhen Municipal Health Commission
# 1  Official Weibo of Shanghai Municipal Health Co...
#
#                                                 link  Unnamed: 21  \
# 0  http://wjw.sz.gov.cn/wzx/202001/t20200120_1898...          NaN
# 1  https://www.weibo.com/2372649470/IqogQhgfa?fro...          NaN
#
# ...

# %%
corona_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 27 columns):
# id                       1085 non-null int64
# case_in_country          888 non-null float64
# reporting date           1084 non-null object
# Unnamed: 3               0 non-null float64
# summary                  1080 non-null object
# location                 1085 non-null object
# country                  1085 non-null object
# gender                   902 non-null object
# age                      843 non-null float64
# symptom_onset            563 non-null object
# If_onset_approximated    560 non-null float64
# hosp_visit_date          507 non-null object
# exposure_start           128 non-null object
# exposure_end             341 non-null object
# visiting Wuhan           1085 non-null int64
# from Wuhan               1081 non-null float64
# death                    1085 non-null object
# recovered                1085 non-null object
# ...

# %%
corona_df.shape
# Out:
# (1085, 27)

# %%
corona_df.isnull().sum()
# Out:
# id                          0
# case_in_country           197
# reporting date              1
# Unnamed: 3               1085
# summary                     5
# location                    0
# country                     0
# gender                    183
# age                       242
# symptom_onset             522
# If_onset_approximated     525
# hosp_visit_date           578
# exposure_start            957
# exposure_end              744
# visiting Wuhan              0
# from Wuhan                  4
# death                       0
# recovered                   0
# symptom                   815
# source                      0
# link                        0
# Unnamed: 21              1085
# Unnamed: 22              1085
# Unnamed: 23              1085
# Unnamed: 24              1085
# Unnamed: 25              1085
# Unnamed: 26              1085
# dtype: int64

# %%
corona_df=corona_df.drop(['link','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26'],axis=1)
corona_df.head()
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
# 3   4              NaN      1/21/2020         NaN
# 4   5              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0   China    male  66.0      01/03/20                    0.0        01/11/20
# ...

# %%
corona_df.head()
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
# 3   4              NaN      1/21/2020         NaN
# 4   5              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0   China    male  66.0      01/03/20                    0.0        01/11/20
# ...

# %%
corona_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 20 columns):
# id                       1085 non-null int64
# case_in_country          888 non-null float64
# reporting date           1084 non-null object
# Unnamed: 3               0 non-null float64
# summary                  1080 non-null object
# location                 1085 non-null object
# country                  1085 non-null object
# gender                   902 non-null object
# age                      843 non-null float64
# symptom_onset            563 non-null object
# If_onset_approximated    560 non-null float64
# hosp_visit_date          507 non-null object
# exposure_start           128 non-null object
# exposure_end             341 non-null object
# visiting Wuhan           1085 non-null int64
# from Wuhan               1081 non-null float64
# death                    1085 non-null object
# recovered                1085 non-null object
# ...

# %%
corona_df=corona_df.drop(['summary','id'],axis=1)
corona_df.head()
# Out:
#    case_in_country reporting date  Unnamed: 3             location country  \
# 0              NaN      1/20/2020         NaN  Shenzhen, Guangdong   China
# 1              NaN      1/20/2020         NaN             Shanghai   China
# 2              NaN      1/21/2020         NaN             Zhejiang   China
# 3              NaN      1/21/2020         NaN              Tianjin   China
# 4              NaN      1/21/2020         NaN              Tianjin   China
#
#    gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0    male  66.0      01/03/20                    0.0        01/11/20
# 1  female  56.0     1/15/2020                    0.0       1/15/2020
# 2    male  46.0      01/04/20                    0.0       1/17/2020
# 3  female  60.0           NaN                    NaN       1/19/2020
# 4    male  58.0           NaN                    NaN       1/14/2020
#
#   exposure_start exposure_end  visiting Wuhan  from Wuhan death recovered  \
# ...

# %%
corona_df=corona_df.drop(['Unnamed: 3','If_onset_approximated','exposure_start','exposure_end','source'],axis=1)
corona_df.head()
# Out:
#    case_in_country reporting date             location country  gender   age  \
# 0              NaN      1/20/2020  Shenzhen, Guangdong   China    male  66.0
# 1              NaN      1/20/2020             Shanghai   China  female  56.0
# 2              NaN      1/21/2020             Zhejiang   China    male  46.0
# 3              NaN      1/21/2020              Tianjin   China  female  60.0
# 4              NaN      1/21/2020              Tianjin   China    male  58.0
#
#   symptom_onset hosp_visit_date  visiting Wuhan  from Wuhan death recovered  \
# 0      01/03/20        01/11/20               1         0.0     0         0
# 1     1/15/2020       1/15/2020               0         1.0     0         0
# 2      01/04/20       1/17/2020               0         1.0     0         0
# 3           NaN       1/19/2020               1         0.0     0         0
# 4           NaN       1/14/2020               0         0.0     0         0
#
#   symptom
# 0     NaN
# 1     NaN
# 2     NaN
# ...

# %%
sym=corona_df['symptom'].dropna()
sym.head()
# Out:
# 194    feaver, cough, difficult in breathing
# 195    feaver, cough, difficult in breathing
# 196                                    fever
# 236                                    fever
# 240                                    fever
# Name: symptom, dtype: object

# %%
corona_df_x=corona_df.drop(['symptom'],axis=1)
corona_df_x.head()
# Out:
#    case_in_country reporting date             location country  gender   age  \
# 0              NaN      1/20/2020  Shenzhen, Guangdong   China    male  66.0
# 1              NaN      1/20/2020             Shanghai   China  female  56.0
# 2              NaN      1/21/2020             Zhejiang   China    male  46.0
# 3              NaN      1/21/2020              Tianjin   China  female  60.0
# 4              NaN      1/21/2020              Tianjin   China    male  58.0
#
#   symptom_onset hosp_visit_date  visiting Wuhan  from Wuhan death recovered
# 0      01/03/20        01/11/20               1         0.0     0         0
# 1     1/15/2020       1/15/2020               0         1.0     0         0
# 2      01/04/20       1/17/2020               0         1.0     0         0
# 3           NaN       1/19/2020               1         0.0     0         0
# 4           NaN       1/14/2020               0         0.0     0         0

# %%
corona_df_x=pd.concat([corona_df,sym],axis=1)
corona_df_x
# Out:
#       case_in_country reporting date             location      country  \
# 0                 NaN      1/20/2020  Shenzhen, Guangdong        China
# 1                 NaN      1/20/2020             Shanghai        China
# 2                 NaN      1/21/2020             Zhejiang        China
# 3                 NaN      1/21/2020              Tianjin        China
# 4                 NaN      1/21/2020              Tianjin        China
# ...               ...            ...                  ...          ...
# 1080              2.0      2/25/2020            Innsbruck      Austria
# 1081              1.0      2/24/2020          Afghanistan  Afghanistan
# 1082              1.0      2/26/2020              Algeria      Algeria
# 1083              1.0      2/25/2020              Croatia      Croatia
# 1084              1.0      2/25/2020                 Bern  Switzerland
#
#       gender   age symptom_onset hosp_visit_date  visiting Wuhan  from Wuhan  \
# ...

# %%
corona_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 13 columns):
# case_in_country    888 non-null float64
# reporting date     1084 non-null object
# location           1085 non-null object
# country            1085 non-null object
# gender             902 non-null object
# age                843 non-null float64
# symptom_onset      563 non-null object
# hosp_visit_date    507 non-null object
# visiting Wuhan     1085 non-null int64
# from Wuhan         1081 non-null float64
# death              1085 non-null object
# recovered          1085 non-null object
# symptom            270 non-null object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 110.3+ KB

# %%
corona_df.ipynb.death
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-c8ebf13ddbed> in <module>
# ----> 1 corona_df.ipynb.death
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ipynb'
