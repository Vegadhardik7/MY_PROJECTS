# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"D:\Dig\kc_house_data.csv")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['price'])

# %%
sns.countplot(data['bedrooms'])

# %%
data.corr()         #Shows the correlation
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
data.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='price',y='sqft_living',data=data)

# %%
# Shows the Distributions of prices per bedroom

plt.figure(figsize=(10,7))
sns.boxplot(x='bedrooms',y='price',data=data)

# %%
data.columns        # lat = Lattitude  , long = Longitude
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(y='long',x='price',data=data)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(y='lat',x='price',data=data)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=data)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=data,hue='price')

# %%
data.sort_values('price',ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
# Total number of houses
len(data)
# Out:
# 21613

# %%
# 1% of houses
len(data)*0.01
# Out:
# 216.13

# %%
# Drop 1% of that outliers houses
non_top_1_per = data.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=non_top_1_per,hue='price')

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=non_top_1_per,
                edgecolor=None,palette='RdYlGn',alpha=0.2,hue='price')

# %%
sns.boxplot(x='waterfront',y='price',data=data)

# %% [markdown]
# #### Feature Engineering & Exploratory Data Analysis

# %%
data = data.drop('id',axis=1)

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
# def year_extraction(date):
#         return date.year

data['month']=data['date'].apply(lambda date: date.month)
data['year']=data['date'].apply(lambda date: date.year)

# %%
data.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='month',y='price',data=data)

# %%
data.groupby('month').mean()['price'].plot()

# %%
data.groupby('year').mean()['price'].plot()

# %%
data = data.drop('date',axis=1)

# %%
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# ...

# %%
data['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
data = data.drop('zipcode',axis=1)

# %%
data['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
data['sqft_basement'].value_counts()
# Out:
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# #### train / fit model into training data

# %%
X = data.drop('price',axis=1).values
y= data['price'].values

# %%
from sklearn.model_selection import train_test_split
X_test,X_train,y_test,y_train=train_test_split(X,y,test_size=0.2,random_state=101)

# %% [markdown]
# #### Feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Creating model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (4323, 19)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

# %% [markdown]
# #### Compile our model

# %%
model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# #### Now Train our model

# %%
# After each epochs of training our X_train we will run the test data check our loss on the test data 
# which will help us to keep a track of how well our model is performing not just on our training data but also on our test data

model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,
          epochs=400)
# Out:
# Train on 4323 samples, validate on 17290 samples
# Epoch 1/400
# 4323/4323 [==============================] - 1s 287us/sample - loss: 425318434454.5325 - val_loss: 426758987843.2796
# Epoch 2/400
# 4323/4323 [==============================] - 0s 58us/sample - loss: 425316880381.1575 - val_loss: 426755690516.3734
# Epoch 3/400
# 4323/4323 [==============================] - 0s 63us/sample - loss: 425308843003.9731 - val_loss: 426739359221.8725
# Epoch 4/400
# 4323/4323 [==============================] - 0s 60us/sample - loss: 425274566410.1263 - val_loss: 426675603483.2435
# Epoch 5/400
# 4323/4323 [==============================] - 0s 62us/sample - loss: 425155823569.0992 - val_loss: 426472269566.0160
# Epoch 6/400
# 4323/4323 [==============================] - 0s 57us/sample - loss: 424801003774.4011 - val_loss: 425903076564.1439
# Epoch 7/400
# 4323/4323 [==============================] - 0s 66us/sample - loss: 423912527075.6345 - val_loss: 424583390606.3472
# Epoch 8/400
# ...

# %%
loss_val=pd.DataFrame(model.history.history)

# %%
# loss     =  loss on my training set
# val_loss =  loss on my test set

loss_val
# Out:
#              loss      val_loss
# 0    4.253184e+11  4.267590e+11
# 1    4.253169e+11  4.267557e+11
# 2    4.253088e+11  4.267394e+11
# 3    4.252746e+11  4.266756e+11
# 4    4.251558e+11  4.264723e+11
# ..            ...           ...
# 395  3.190258e+10  3.443242e+10
# 396  3.189035e+10  3.440544e+10
# 397  3.186230e+10  3.440107e+10
# 398  3.182427e+10  3.439957e+10
# 399  3.181334e+10  3.437061e+10
#
# [400 rows x 2 columns]

# %%
loss_val.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

pred = model.predict(X_test)
pred
# Out:
# array([[708350.2 ],
#        [560825.4 ],
#        [620191.1 ],
#        ...,
#        [257612.14],
#        [469272.97],
#        [342891.3 ]], dtype=float32)

# %%
mean_absolute_error(y_test,pred)
# Out:
# 114890.64583343655

# %%
mean_squared_error(y_test,pred)
# Out:
# 34370605415.53221

# %%
np.sqrt(mean_absolute_error(y_test,pred))
# Out:
# 338.9552268861428

# %%
data['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
explained_variance_score(y_test,pred)
# Out:
# 0.7441913322808358

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,pred)
plt.plot(y_test,y_test,'r')

# %%
# Retrain our model on that not_1_percent model

data
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
single_house = data.drop('price',axis=1).iloc[0]

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[277392.94]], dtype=float32)

# %%
data.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# 0  47.5112 -122.257           1340        5650     10  2014
